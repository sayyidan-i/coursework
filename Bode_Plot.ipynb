# %% [markdown]
# <a href="https://colab.research.google.com/github/sayyidan-i/coursework/blob/main/Bode_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import signal
import matplotlib.pyplot as plt

# %%
sys = signal.TransferFunction([1], [1, 3])
w, mag, phase = signal.bode(sys)

# %%
plt.figure()
plt.semilogx(w, mag)    # Bode magnitude plot
plt.figure()
plt.semilogx(w, phase)  # Bode phase plot
plt.show()

# %%
sys = signal.TransferFunction([1], [1, 1, 2])
w, mag, phase = signal.bode(sys)
plt.figure()
plt.semilogx(w, mag)    # Bode magnitude plot
plt.figure()
plt.semilogx(w, phase)  # Bode phase plot
plt.show()

# %%
sys = signal.TransferFunction([10, 30], [1, 3, 4, 4, 0])
w, mag, phase = signal.bode(sys)
plt.figure()
plt.semilogx(w, mag)    # Bode magnitude plot
plt.figure()
plt.semilogx(w, phase)  # Bode phase plot
plt.show()
